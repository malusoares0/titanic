# %% [markdown]
# <br>
#
# ### Importando as bibliotecas
#
# <br>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <br>
#
# ### Carregando os dados e verificando
#
# <br>

# %%
#chamando os arquivos do titanic
train = pd.read_csv("titanic_data_github/train.csv", sep=",")
test = pd.read_csv("titanic_data_github/test.csv", sep=",")
gender_submission = pd.read_csv("titanic_data_github/gender_submission.csv", sep=",")

# %%
#verificando
train.head()

#deu certo
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.shape
# Out:
# (891, 12)

# %%
#verificando
test.head()

#deu certo
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.shape
# Out:
# (418, 11)

# %%
#verificando
gender_submission.head()

#deu certo
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
gender_submission.shape
# Out:
# (418, 2)

# %% [markdown]
# <br>
#
# ### Unindo gender_submission com test
#
# <br>

# %%
#Para juntar gender_submission e test, utilizando a coluna PassengerId (em comum) como chave
df_test = pd.merge(gender_submission, test, on="PassengerId", how="inner")  

#checar a qntd de linhas

# %%
#verificando
df_test

#deu certo
#linhas ok
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %% [markdown]
# <br>
#
# ### Concatenando df_test e train, para ter um único dataframe
#
# <br>

# %%
titanic = pd.concat([train, df_test], axis=0, sort=False).reset_index(drop=True)

# %%
#verificando
titanic

#deu certo
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %%
#fazendo uma cópia do dataframe, para não alterar os dados do df original
df_titanic = titanic.copy()

# %%
#verificando
df_titanic.sample(15)

#deu certo
# Out:
#       PassengerId  Survived  Pclass                                   Name  \
# 653           654         1       3          O'Leary, Miss. Hanora "Norah"
# 89             90         0       3                 Celotti, Mr. Francesco
# 489           490         1       3  Coutts, Master. Eden Leslie "Neville"
# 615           616         1       2                    Herman, Miss. Alice
# 465           466         0       3        Goncalves, Mr. Manuel Estanslas
# 449           450         1       1         Peuchen, Major. Arthur Godfrey
# 622           623         1       3                       Nakid, Mr. Sahid
# 274           275         1       3             Healy, Miss. Hanora "Nora"
# 628           629         0       3              Bostandyeff, Mr. Guentcho
# 1020         1021         0       3                   Petersen, Mr. Marius
# 760           761         0       3                     Garfirth, Mr. John
# 851           852         0       3                    Svensson, Mr. Johan
# 999          1000         0       3       Willer, Mr. Aaron (Abi Weller")"
# 441           442         0       3                        Hampe, Mr. Leon
# 292           293         0       2                 Levy, Mr. Rene Jacques
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 653   female   NaN      0      0              330919   7.8292   NaN        Q
# 89      male  24.0      0      0              343275   8.0500   NaN        S
# 489     male   9.0      1      1          C.A. 37671  15.9000   NaN        S
# 615   female  24.0      1      2              220845  65.0000   NaN        S
# 465     male  38.0      0      0  SOTON/O.Q. 3101306   7.0500   NaN        S
# 449     male  52.0      0      0              113786  30.5000  C104        S
# 622     male  20.0      1      1                2653  15.7417   NaN        C
# 274   female   NaN      0      0              370375   7.7500   NaN        Q
# 628     male  26.0      0      0              349224   7.8958   NaN        S
# 1020    male  24.0      0      0              342441   8.0500   NaN        S
# 760     male   NaN      0      0              358585  14.5000   NaN        S
# 851     male  74.0      0      0              347060   7.7750   NaN        S
# 999     male   NaN      0      0                3410   8.7125   NaN        S
# 441     male  20.0      0      0              345769   9.5000   NaN        S
# 292     male  36.0      0      0       SC/Paris 2163  12.8750     D        C

# %% [markdown]
# <br>
#
# ### Colocando todas as letras dos nomes das colunas em minúsculo
#
# <br>

# %%
df_titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#List comprehension para passar todas as letras das colunas para minúsculas
df_titanic.columns = [col.lower() for col in df_titanic.columns]

# %%
#verificando
df_titanic

#deu certo
# Out:
#       passengerid  survived  pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    name     sex   age  sibsp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       parch              ticket      fare cabin embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %% [markdown]
# <br>
#
# ### Renomeando algumas colunas
# <br>

# %%
#para renomear as colunas
df_titanic.rename(columns={'passengerid':'passenger_id',
                           'pclass': 'p_class'}, inplace=True)

#o inplace=True é usado para que o df não seja mostrado na hora que você roda o comando.

# %%
#verificando
df_titanic

#deu certo
# Out:
#       passenger_id  survived  p_class  \
# 0                1         0        3
# 1                2         1        1
# 2                3         1        3
# 3                4         1        1
# 4                5         0        3
# ...            ...       ...      ...
# 1304          1305         0        3
# 1305          1306         1        1
# 1306          1307         0        3
# 1307          1308         0        3
# 1308          1309         0        3
#
#                                                    name     sex   age  sibsp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       parch              ticket      fare cabin embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %% [markdown]
# <br>
#
# ### Exportando o arquivo limpo
#
# <br>

# %%
df_titanic.to_csv("titanic_data_github/titanic_github_limpo.csv", sep=",", index=False)
